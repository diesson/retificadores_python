# %%
################## I M P O R T ##################
import importlib
import matplotlib.pyplot as plt
from plot_funcao import *
import scipy.integrate as integrate
from funcoes import *
#################### C O D E ####################
 
Vin = 220
z = 1+1j
T = 2*pi
func = '5*sin(x)'
func1 = 'sqrt(2)*220*heaviside(x, 0)'

v = Vrms(func, T, 0, pi)
i = Imed(v, z)

print("V = ", v)
if i.imag != 0:
    print("I = ", cm.polar(i)[0], "L", cm.polar(i)[1])
else:
    print("I = ", i)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13.2, 6), sharey=True, sharex=True)
plot_fx(func, xlim=(0, 3*T), ax=ax1)
plot_fx_diodo(func, T, ax2, pi/3, 1.8*pi)
# Out:
# V =  2.5
# I =  1.7677669529663689 L -0.7853981633974483
